# %% [markdown]
# # Analiza podatkov s pandas
#
# Povzeto po [https://github.com/matijapretnar/programiranje-1/tree/master/03-knjiznica-pandas](https://github.com/matijapretnar/programiranje-1/tree/master/03-knjiznica-pandas).
#
# [Pandas quick-start guide](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# [Pandas documentation](http://pandas.pydata.org/pandas-docs/stable/)
# [Lecture notes on pandas](../predavanja/analiza-filmov.ipynb)

# %% [markdown]
# ### Naložimo pandas in podatke

# %%
# naložimo paket
import pandas as pd

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 10 vrstic
pd.set_option("display.max_rows", 10)

# izberemo interaktivni "notebook" stil risanja
# %matplotlib inline

# naložimo razpredelnico, s katero bomo delali
FILMI = pd.read_csv("filmi.csv", index_col="id")

# %% [markdown]
# Poglejmo si podatke.

# %%
FILMI
# Out:
#                                                      naslov  dolzina  leto  \
# id
# 4972                                  The Birth of a Nation      195  1915
# 6864                                            Intolerance      197  1916
# 9968                                        Broken Blossoms       90  1919
# 10323                           The Cabinet of Dr. Caligari       67  1920
# 12349                                               The Kid       68  1921
# ...                                                     ...      ...   ...
# 18568902                                 Kaun Pravin Tambe?      134  2022
# 18689424  Batman v Superman: Dawn of Justice - Ultimate ...      182  2016
# 18968540                                        Incantation      110  2022
# 20850406                                         Sita Ramam      163  2022
# 21279138                                 Maid in Malacañang      114  2022
#
#           ocena  metascore  glasovi    zasluzek     oznaka  \
# id
# 4972        6.2        NaN    24890  10000000.0      TV-PG
# 6864        7.7       99.0    15670   2180000.0     Passed
# 9968        7.3        NaN    10423         NaN  Not Rated
# 10323       8.0        NaN    64133         NaN  Not Rated
# 12349       8.3        NaN   126513   5450000.0     Passed
# ...         ...        ...      ...         ...        ...
# 18568902    8.4        NaN    10163         NaN        NaN
# 18689424    7.1        NaN    57662         NaN          R
# 18968540    6.2        NaN    12366         NaN      TV-MA
# 20850406    8.5        NaN    38490         NaN        NaN
# 21279138    3.9        NaN    15273         NaN        NaN
#
#                                                        opis
# id
# 4972      The Stoneman family finds its friendship with ...
# 6864      The story of a poor young woman separated by p...
# 9968      A frail waif, abused by her brutal boxer fathe...
# 10323     Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 12349     The Tramp cares for an abandoned child, but ev...
# ...                                                     ...
# 18568902  An indian cricketer who shows persistence and ...
# 18689424  Batman is manipulated by Lex Luthor to fear Su...
# 18968540  Six years ago, Li Ronan was cursed after break...
# 20850406  An orphan soldier, Lieutenant Ram's life chang...
# 21279138  The Last Days of Ferdinand and Imelda Marcos t...
#
# [9999 rows x 9 columns]

# %% [markdown]
# ## Proučevanje podatkov
#
# Razvrstite podatke po ocenah.

# %%
FILMI.sort_values("ocena", inplace=True, ascending=False)
FILMI
# Out:
#                             naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 15327088                   Kantara      148  2022    9.4        NaN    33294
# 111161    The Shawshank Redemption      142  1994    9.3       81.0  2651625
# 252487             The Chaos Class       87  1975    9.2        NaN    40747
# 68646                The Godfather      175  1972    9.2      100.0  1838099
# 108052            Schindler's List      195  1993    9.0       94.0  1343684
# ...                            ...      ...   ...    ...        ...      ...
# 421051           Daniel the Wizard       81  2004    1.2        NaN    14413
# 6038600                   Smolensk      120  2016    1.2        NaN    39704
# 7886848                    Sadak 2      133  2020    1.1        NaN    95865
# 5988370                       Reis      108  2017    1.0        NaN    73382
# 7221896               Cumali Ceber      100  2017    1.0        NaN    38958
#
#              zasluzek     oznaka  \
# id
# 15327088          NaN        NaN
# 111161     28341469.0          R
# 252487            NaN        NaN
# 68646     134966411.0          R
# 108052     96898818.0          R
# ...               ...        ...
# 421051            NaN  Not Rated
# 6038600           NaN        NaN
# 7886848           NaN      TV-MA
# 5988370           NaN        NaN
# 7221896           NaN        NaN
#
#                                                        opis
# id
# 15327088  It involves culture of Kambla and Bhootha Kola...
# 111161    Two imprisoned men bond over a number of years...
# 252487    Lazy, uneducated students share a very close b...
# 68646     The aging patriarch of an organized crime dyna...
# 108052    In German-occupied Poland during World War II,...
# ...                                                     ...
# 421051    Evil assassins want to kill Daniel Kublbock, t...
# 6038600   An inspired story of people affected by the tr...
# 7886848   The film picks up where Sadak left off, revolv...
# 5988370   A drama about the early life of Recep Tayyip E...
# 7221896   Cumali Ceber goes to a vacation with his child...
#
# [9999 rows x 9 columns]

# %% [markdown]
# Poberite stolpec ocen.

# %%
ocene = FILMI["ocena"]
ocene
# Out:
# id
# 15327088    9.4
# 111161      9.3
# 252487      9.2
# 68646       9.2
# 108052      9.0
#            ...
# 421051      1.2
# 6038600     1.2
# 7886848     1.1
# 5988370     1.0
# 7221896     1.0
# Name: ocena, Length: 9999, dtype: float64

# %% [markdown]
# Ukaza `filmi['ocena']` in `filmi[['ocena']]` sta različna:

# %%
print(type(FILMI['ocena']))
print(type(FILMI[['ocena']]))
# Out:
# <class 'pandas.Series'>
# <class 'pandas.DataFrame'>

# %% [markdown]
# Stolpci objekta `DataFrame` so tipa `Series`. Z enojnimi oklepaji poberemo `Series`, z dvojnimi oklepaji pa `DataFrame` podtabelo. Večina operacij (grouping, joining, plotting,  filtering, ...) deluje na `DataFrame`.
#
# Tip `Series` se uporablja ko želimo npr. dodati stolpec.

# %% [markdown]
# Zaokrožite stolpec ocen z funkcijo `round()` in dobljeni `Series` shranite v `zaokrozena_ocena`.

# %%
zaokorozene_ocene = ocene.apply(round)
zaokorozene_ocene
# Out:
# id
# 15327088    9
# 111161      9
# 252487      9
# 68646       9
# 108052      9
#            ..
# 421051      1
# 6038600     1
# 7886848     1
# 5988370     1
# 7221896     1
# Name: ocena, Length: 9999, dtype: int64

# %% [markdown]
# Dodajte zaokrožene vrednosti v podatke.

# %%
FILMI["zaokrozena ocena"] = zaokorozene_ocene
FILMI
# Out:
#                             naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 15327088                   Kantara      148  2022    9.4        NaN    33294
# 111161    The Shawshank Redemption      142  1994    9.3       81.0  2651625
# 252487             The Chaos Class       87  1975    9.2        NaN    40747
# 68646                The Godfather      175  1972    9.2      100.0  1838099
# 108052            Schindler's List      195  1993    9.0       94.0  1343684
# ...                            ...      ...   ...    ...        ...      ...
# 421051           Daniel the Wizard       81  2004    1.2        NaN    14413
# 6038600                   Smolensk      120  2016    1.2        NaN    39704
# 7886848                    Sadak 2      133  2020    1.1        NaN    95865
# 5988370                       Reis      108  2017    1.0        NaN    73382
# 7221896               Cumali Ceber      100  2017    1.0        NaN    38958
#
#              zasluzek     oznaka  \
# id
# 15327088          NaN        NaN
# 111161     28341469.0          R
# 252487            NaN        NaN
# 68646     134966411.0          R
# 108052     96898818.0          R
# ...               ...        ...
# 421051            NaN  Not Rated
# 6038600           NaN        NaN
# 7886848           NaN      TV-MA
# 5988370           NaN        NaN
# 7221896           NaN        NaN
#
#                                                        opis  zaokrozena ocena
# id
# 15327088  It involves culture of Kambla and Bhootha Kola...                 9
# 111161    Two imprisoned men bond over a number of years...                 9
# 252487    Lazy, uneducated students share a very close b...                 9
# 68646     The aging patriarch of an organized crime dyna...                 9
# 108052    In German-occupied Poland during World War II,...                 9
# ...                                                     ...               ...
# 421051    Evil assassins want to kill Daniel Kublbock, t...                 1
# 6038600   An inspired story of people affected by the tr...                 1
# 7886848   The film picks up where Sadak left off, revolv...                 1
# 5988370   A drama about the early life of Recep Tayyip E...                 1
# 7221896   Cumali Ceber goes to a vacation with his child...                 1
#
# [9999 rows x 10 columns]

# %% [markdown]
# Odstranite novo dodani stolpec z metodo `.drop()` z podanim `columns = ` argumentom.

# %%
FILMI.drop(columns=["zaokrozena ocena"], inplace=True)
FILMI
# Out:
#                             naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 15327088                   Kantara      148  2022    9.4        NaN    33294
# 111161    The Shawshank Redemption      142  1994    9.3       81.0  2651625
# 252487             The Chaos Class       87  1975    9.2        NaN    40747
# 68646                The Godfather      175  1972    9.2      100.0  1838099
# 108052            Schindler's List      195  1993    9.0       94.0  1343684
# ...                            ...      ...   ...    ...        ...      ...
# 421051           Daniel the Wizard       81  2004    1.2        NaN    14413
# 6038600                   Smolensk      120  2016    1.2        NaN    39704
# 7886848                    Sadak 2      133  2020    1.1        NaN    95865
# 5988370                       Reis      108  2017    1.0        NaN    73382
# 7221896               Cumali Ceber      100  2017    1.0        NaN    38958
#
#              zasluzek     oznaka  \
# id
# 15327088          NaN        NaN
# 111161     28341469.0          R
# 252487            NaN        NaN
# 68646     134966411.0          R
# 108052     96898818.0          R
# ...               ...        ...
# 421051            NaN  Not Rated
# 6038600           NaN        NaN
# 7886848           NaN      TV-MA
# 5988370           NaN        NaN
# 7221896           NaN        NaN
#
#                                                        opis
# id
# 15327088  It involves culture of Kambla and Bhootha Kola...
# 111161    Two imprisoned men bond over a number of years...
# 252487    Lazy, uneducated students share a very close b...
# 68646     The aging patriarch of an organized crime dyna...
# 108052    In German-occupied Poland during World War II,...
# ...                                                     ...
# 421051    Evil assassins want to kill Daniel Kublbock, t...
# 6038600   An inspired story of people affected by the tr...
# 7886848   The film picks up where Sadak left off, revolv...
# 5988370   A drama about the early life of Recep Tayyip E...
# 7221896   Cumali Ceber goes to a vacation with his child...
#
# [9999 rows x 9 columns]

# %% [markdown]
# ### Opomba: slice
# Izbira podtabele ustvari t.i. "rezino" oz. "slice".
# Slice ni kopija tabele, temveč zgolj sklic na izvorno tabelo,
# in je zato ne moremo spreminjati.
# Če želimo kopijo, uporabimo metodo `.copy()` na rezini, ki jo nato lahko spreminjamo.

# %% [markdown]
# Izberite podtabelo s stolpci `naslov`, `leto`, in `glasovi`, kateri nato dodate solpec z zaokroženimi ocenami.

# %%
poenostavljena_tabela = FILMI[["naslov", "leto", "glasovi"]].copy()
poenostavljena_tabela["zaokrozena ocena"] = zaokorozene_ocene
poenostavljena_tabela
# Out:
#                             naslov  leto  glasovi  zaokrozena ocena
# id
# 15327088                   Kantara  2022    33294                 9
# 111161    The Shawshank Redemption  1994  2651625                 9
# 252487             The Chaos Class  1975    40747                 9
# 68646                The Godfather  1972  1838099                 9
# 108052            Schindler's List  1993  1343684                 9
# ...                            ...   ...      ...               ...
# 421051           Daniel the Wizard  2004    14413                 1
# 6038600                   Smolensk  2016    39704                 1
# 7886848                    Sadak 2  2020    95865                 1
# 5988370                       Reis  2017    73382                 1
# 7221896               Cumali Ceber  2017    38958                 1
#
# [9999 rows x 4 columns]

# %% [markdown]
# ### Filtracija
#
# Ustvarite filter, ki izbere filme, ki so izšli pred 1930, in filter za filme po 2017.
# Združite ju za izbor filmov, ki so izšli pred 1930 ali po 2017.

# %%
filter_pred_1930 = FILMI["leto"] < 1930
filter_po_2017 = FILMI["leto"] > 2017
filter_skrajni = filter_pred_1930 | filter_po_2017
filter_skrajni = (FILMI["leto"] < 1930) | (FILMI["leto"] > 2017)
FILMI[filter_skrajni]
# Out:
#                                                      naslov  dolzina  leto  \
# id
# 15327088                                            Kantara      148  2022
# 16492678  Demon Slayer: Kimetsu no Yaiba - Tsuzumi Mansi...       87  2021
# 15097216                                           Jai Bhim      164  2021
# 9263550                          Rocketry: The Nambi Effect      157  2022
# 7466810                                         777 Charlie      164  2022
# ...                                                     ...      ...   ...
# 10888594                                              Radhe      135  2021
# 7431594                                              Race 3      160  2018
# 8402090                                      Cumali Ceber 2      100  2018
# 14723224                              The Cost of Deception      125  2021
# 7886848                                             Sadak 2      133  2020
#
#           ocena  metascore  glasovi   zasluzek     oznaka  \
# id
# 15327088    9.4        NaN    33294        NaN        NaN
# 16492678    9.0        NaN    12634        NaN        NaN
# 15097216    8.9        NaN   199511        NaN      TV-MA
# 9263550     8.9        NaN    47460        NaN        NaN
# 7466810     8.9        NaN    26856        NaN        NaN
# ...         ...        ...      ...        ...        ...
# 10888594    1.9        NaN   177814        NaN      TV-MA
# 7431594     1.9        NaN    46781  1690861.0  Not Rated
# 8402090     1.7        NaN    10791        NaN        NaN
# 14723224    1.5        NaN    38040        NaN        NaN
# 7886848     1.1        NaN    95865        NaN      TV-MA
#
#                                                        opis
# id
# 15327088  It involves culture of Kambla and Bhootha Kola...
# 16492678  Tanjiro ventures to the south-southeast where ...
# 15097216  When a tribal man is arrested for a case of al...
# 9263550   Based on the life of Indian Space Research Org...
# 7466810   Dharma is stuck in a rut with his negative and...
# ...                                                     ...
# 10888594  After taking the dreaded gangster Gani Bhai, A...
# 7431594   Relationships and loyalties of a criminal fami...
# 8402090   Cumali Ceber learns about the demolition of th...
# 14723224  When a young, ambitious market researcher find...
# 7886848   The film picks up where Sadak left off, revolv...
#
# [1402 rows x 9 columns]

# %% [markdown]
# Definirajte funkcijo, ki preveri ali niz vsebuje kvečjemu dve besedi. Nato s pomočjo `.apply()` izberite vse filme z imeni, krajšimi od dveh besed in oceno nad 8.

# %%
def najvec_dve_besedi(niz):
    return len(niz.split()) <= 2

filter_kratki_sladki = FILMI["naslov"].apply(najvec_dve_besedi) & (FILMI["ocena"] > 8)
FILMI[filter_kratki_sladki]
# Out:
#                     naslov  dolzina  leto  ocena  metascore  glasovi  \
# id
# 15327088           Kantara      148  2022    9.4        NaN    33294
# 68646        The Godfather      175  1972    9.2      100.0  1838099
# 108052    Schindler's List      195  1993    9.0       94.0  1343684
# 5354160        Mirror Game      147  2016    9.0        NaN    27034
# 15097216          Jai Bhim      164  2021    8.9        NaN   199511
# ...                    ...      ...   ...    ...        ...      ...
# 73707               Sholay      162  1975    8.1        NaN    55962
# 4934950             Talvar      132  2015    8.1        NaN    35581
# 1639426              Udaan      134  2010    8.1        NaN    45228
# 1205489        Gran Torino      116  2008    8.1       72.0   772762
# 14429         Safety Last!       74  1923    8.1        NaN    20887
#
#              zasluzek     oznaka  \
# id
# 15327088          NaN        NaN
# 68646     134966411.0          R
# 108052     96898818.0          R
# 5354160           NaN        NaN
# 15097216          NaN      TV-MA
# ...               ...        ...
# 73707             NaN  Not Rated
# 4934950      342370.0  Not Rated
# 1639426        7461.0  Not Rated
# 1205489   148095302.0          R
# 14429       1359903.0  Not Rated
#
#                                                        opis
# id
# 15327088  It involves culture of Kambla and Bhootha Kola...
# 68646     The aging patriarch of an organized crime dyna...
# 108052    In German-occupied Poland during World War II,...
# 5354160   Ayna is an actor and the prison is his stage. ...
# 15097216  When a tribal man is arrested for a case of al...
# ...                                                     ...
# 73707     After his family is murdered by a notorious an...
# 4934950   An experienced investigator confronts several ...
# 1639426   Expelled from his school, a 16-year old boy re...
# 1205489   Disgruntled Korean War veteran Walt Kowalski s...
# 14429     A boy leaves his small country town and heads ...
#
# [269 rows x 9 columns]

# %% [markdown]
# ### Manjkajoče vrednosti
#
# Koliko filmov ima neznan zaslužek? Koliko filmov ima znan zaslužek?

# %%
filter_neznan_zasluzek = FILMI["zasluzek"].isna()
filter_znan_zasluzek = FILMI["zasluzek"].notna()
filter_znan_zasluzek2 = ~filter_neznan_zasluzek

filmi_neznan_zasluzek = sum(filter_neznan_zasluzek)
filmi_znan_zasluzek = sum(filter_znan_zasluzek)
filmi_znan_zasluzek2 = sum(filter_znan_zasluzek2)

print(filmi_neznan_zasluzek, filmi_znan_zasluzek, filmi_znan_zasluzek2)
# Out:
# 2741 7258 7258

# %% [markdown]
# ### Histogrami
#
# Združite filme po (zaokroženih) ocenah in jih preštejte.

# %%
po_ocenah = poenostavljena_tabela.groupby(by=["zaokrozena ocena"]).size()
po_ocenah
# Out:
# zaokrozena ocena
# 1       7
# 2      33
# 3      55
# 4     223
# 5     856
# 6    3274
# 7    3554
# 8    1932
# 9      65
# dtype: int64

# %% [markdown]
# Naredite stolpični diagram teh podatkov.

# %%
po_ocenah.plot.bar()
# Out:
# <Axes: xlabel='zaokrozena ocena'>

# %% [markdown]
# Tabele imajo metodo `.hist()`, ki omogoča izgradnjo histogramov za stolpce. Uporabite to metodo za prikaz poenostavljenih podatkov.

# %%
poenostavljena_tabela.hist()
# Out:
# array([[<Axes: title={'center': 'leto'}>,
#         <Axes: title={'center': 'glasovi'}>],
#        [<Axes: title={'center': 'zaokrozena ocena'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Izris povprečne dolžine filma glede na leto

# %%
FILMI[["leto", "dolzina"]].groupby(by=["leto"]).mean().plot(ylabel="povprečna dolžina v minutah")
# Out:
# <Axes: xlabel='leto', ylabel='povprečna dolžina v minutah'>

# %% [markdown]
# ### Izris skupnega zasluzka za posamezno leto

# %%
FILMI[["leto", "zasluzek"]].groupby(by=["leto"]).sum().plot()
# Out:
# <Axes: xlabel='leto'>
